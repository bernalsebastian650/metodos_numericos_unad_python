# %% [markdown]
# #Ecuaciones Diferenciales Ordinarias
#
# #Ejecicio 3
#
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# # Paso 1: Genere una gráfica que incluya las solucionespor cada uno de los métodos, con tamañosde paso ℎ=0.5

# %%
import matplotlib.pyplot as plt                  # Importamos librerias para gráficar 
import numpy as np                               # Importamos librerias numpy
import scipy.special as sp

def fun(x,y):                                                                    
    return (2*x*y**0.5)  

# dy/dx = f(x,y) en el intervalo[0,1] con y(0) = 1
# h es el tamaño de paso 

# Runge-Kutta 1er Orden
def runge_kutta_1(f, a, b, h, y0):
  x = [a]
  y = [y0]
  while x [-1] < b:
    y.append(y[-1] + f(x[-1], y[-1]) * h)
    x.append(x[-1] + h)
  return x, y


# Runge-kutta 2do Orden

def runge_kutta_2(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [a]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 3/4 * h, y[-1] + 3/4 * k1 * h)
        y.append(y[-1] + (1/3 * k1 + 2/3 * k2) * h)
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y

# Runge-kutta 4to Orden

def runge_kutta_4(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [0]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k1 * h)
        k3 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k2 * h)
        k4 = f(x[-1] + 0.5 * h, y[-1] + k3 * h)
        y.append(y[-1] + (h/6) * (k1 + 2 * k2 + 2 * k3 + 4))
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y


h = 0.5                                                                          # Valor del tamaño de paso
print("Tamaño de paso(h): ", h)                                                  # Imprimimos el valor del tamaño de paso
x1, y1 = runge_kutta_1(fun, 0, 100, h, 0)
x2, y2 = runge_kutta_2(fun, 0, 100, h, 0)
x4, y4 = runge_kutta_4(fun, 0, 100, h, 0)
x5 = np.arange(0, 100, 0.01)
y5 = 25 -25 * np.exp(-0.025 * x5)

# Gráficas

plt.figure(figsize=(16,10), dpi= 80)
plt.plot(x1, y1, label = "RK 1er Orden")
plt.plot(x2, y2, label = "RK 2do Orden")
plt.plot(x4, y4, label = "RK 4to Orden")
plt.plot(x5, y5, label = "Sol Real")
plt.legend()
plt.show()
# Out:
# Tamaño de paso(h):  0.5

# %% [markdown]
# # Paso 2: Genere una gráfica que incluya las solucionespor cada uno de los métodos, con tamañosde paso ℎ=0.1

# %%
import matplotlib.pyplot as plt                  # Importamos librerias para gráficar 
import numpy as np                               # Importamos librerias numpy
import scipy.special as sp

def fun(x,y):                                                                    
    return (2*x*y**0.5)  

# dy/dx = f(x,y) en el intervalo[0,1] con y(0) = 1
# h es el tamaño de paso 

# Runge-Kutta 1er Orden
def runge_kutta_1(f, a, b, h, y0):
  x = [a]
  y = [y0]
  while x [-1] < b:
    y.append(y[-1] + f(x[-1], y[-1]) * h)
    x.append(x[-1] + h)
  return x, y


# Runge-kutta 2do Orden

def runge_kutta_2(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [a]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 3/4 * h, y[-1] + 3/4 * k1 * h)
        y.append(y[-1] + (1/3 * k1 + 2/3 * k2) * h)
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y

# Runge-kutta 4to Orden

def runge_kutta_4(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [0]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k1 * h)
        k3 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k2 * h)
        k4 = f(x[-1] + 0.5 * h, y[-1] + k3 * h)
        y.append(y[-1] + (h/6) * (k1 + 2 * k2 + 2 * k3 + 4))
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y


h = 0.1                                                                         # Valor del tamaño de paso
print("Tamaño de paso(h): ", h)                                                  # Imprimimos el valor del tamaño de paso
x1, y1 = runge_kutta_1(fun, 0, 100, h, 0)
x2, y2 = runge_kutta_2(fun, 0, 100, h, 0)
x4, y4 = runge_kutta_4(fun, 0, 100, h, 0)
x5 = np.arange(0, 100, 0.01)
y5 = 25 -25 * np.exp(-0.025 * x5)

# Gráficas

plt.figure(figsize=(16,10), dpi= 80)
plt.plot(x1, y1, label = "RK 1er Orden")
plt.plot(x2, y2, label = "RK 2do Orden")
plt.plot(x4, y4, label = "RK 4to Orden")
plt.plot(x5, y5, label = "Sol Real")
plt.legend()
plt.show()
# Out:
# Tamaño de paso(h):  0.1

# %% [markdown]
# # Paso 3: Genere una gráfica que incluya las solucionespor cada uno de los métodos, con tamañosde paso ℎ=0.05

# %%
import matplotlib.pyplot as plt                  # Importamos librerias para gráficar 
import numpy as np                               # Importamos librerias numpy
import scipy.special as sp

def fun(x,y):                                                                    
    return (2*x*y**0.5)  

# dy/dx = f(x,y) en el intervalo[0,1] con y(0) = 1
# h es el tamaño de paso 

# Runge-Kutta 1er Orden
def runge_kutta_1(f, a, b, h, y0):
  x = [a]
  y = [y0]
  while x [-1] < b:
    y.append(y[-1] + f(x[-1], y[-1]) * h)
    x.append(x[-1] + h)
  return x, y


# Runge-kutta 2do Orden

def runge_kutta_2(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [a]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 3/4 * h, y[-1] + 3/4 * k1 * h)
        y.append(y[-1] + (1/3 * k1 + 2/3 * k2) * h)
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y

# Runge-kutta 4to Orden

def runge_kutta_4(f, a, b, h, y0):                                               # Definimos la función y asignamos datos
    x = [0]                                                                      # Asignamos el valor de a para x
    y = [y0]                                                                     # Asignamos el valor de a para y
    while x[-1] < b:                                                             # Condición para plicar el método para y y x
        k1 = f(x[-1], y[-1])
        k2 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k1 * h)
        k3 = f(x[-1] + 0.5 * h, y[-1] + 0.5 * k2 * h)
        k4 = f(x[-1] + 0.5 * h, y[-1] + k3 * h)
        y.append(y[-1] + (h/6) * (k1 + 2 * k2 + 2 * k3 + 4))
        x.append(x[-1] + h)
    return x, y                                                                  # Devuelve los valores de x y de y


h = 0.05                                                                          # Valor del tamaño de paso
print("Tamaño de paso(h): ", h)                                                  # Imprimimos el valor del tamaño de paso
x1, y1 = runge_kutta_1(fun, 0, 100, h, 0)
x2, y2 = runge_kutta_2(fun, 0, 100, h, 0)
x4, y4 = runge_kutta_4(fun, 0, 100, h, 0)
x5 = np.arange(0, 100, 0.01)
y5 = 25 -25 * np.exp(-0.025 * x5)

# Gráficas

plt.figure(figsize=(16,10), dpi= 80)
plt.plot(x1, y1, label = "RK 1er Orden")
plt.plot(x2, y2, label = "RK 2do Orden")
plt.plot(x4, y4, label = "RK 4to Orden")
plt.plot(x5, y5, label = "Sol Real")
plt.legend()
plt.show()
# Out:
# Tamaño de paso(h):  0.05

# %% [markdown]
# # Analisis
# el resultado con los diferentes pasos mencionados en el ejercicio varia los resultados dependiendo el metodoa utilizar.

# %% [markdown]
# # Bibliografia:
#
# * Canale,  R.  P.  y  P.  Canale,  R.  (2007).  Métodos  numéricos  para ingenieros    (5a.    ed.).    México    D.F,    Mexico:    McGraw-Hill Interamericana. (pp. 709–715, 719–751).
# * https://www.youtube.com/watch?v=DUArXaNhnk4
